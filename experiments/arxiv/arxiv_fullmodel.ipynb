# %%
import sys
sys.path.append('./../')

# %%
import sparsedense as spd
import helpertests as tst

# %%
import importlib
importlib.reload(spd)
importlib.reload(tst)
# Out:
# <module 'helpertests' from './..\\helpertests.py'>

# %%
import numpy as np
import networkx as nx
import pickle

# %%
links = np.genfromtxt('arxiv.tsv', delimiter='\t', dtype=int)
g = nx.Graph()
g.add_edges_from(links)
net = nx.adjacency_matrix(g).toarray().astype(int)
for i in range(net.shape[0]):
    net[i, i] = 1

# %%
alpha0 = 3.
sigma0 = .95
c0 = 25.
lamb0 = 2000.

#model = spd.NetworkFull(net, links, alpha=alpha0, sigma=sigma0, c=c0, lamb=lamb0)

# %%
with open('arxiv_king.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
save_every = 1
write_every = 1
niter = 10

model.sample(
    num_iters= niter,
    save_every = save_every,  
    write_every = write_every,
    verbose = True,
    sample_hypers = False,
    optim_hypers = True,
    num_sm = 1,
    hyper_start = 0,
    num_hyper = 50,
    optim_momentum = 0.1,
    do_gibbs = False,
    filename='arxiv.pkl')
# Out:
# iter:     0, K: 14476, alpha:    3.000, sigma: 0.950, c:   25.000, lamb:  7210, lp:  -233389.347
# iter:     1, K: 14476, alpha:    3.258, sigma: 0.532, c:   25.022, lamb:  7126, lp:  -206793.294
# writing to file...
# done!
# iter:     2, K: 14476, alpha:    3.479, sigma: 0.518, c:   25.038, lamb:  7345, lp:  -206731.101
# writing to file...
# done!
# iter:     3, K: 14476, alpha:    3.677, sigma: 0.509, c:   25.053, lamb:  7259, lp:  -206683.379
# writing to file...
# done!
# iter:     4, K: 14476, alpha:    3.854, sigma: 0.502, c:   25.068, lamb:  7349, lp:  -206645.373
# writing to file...
# done!
# iter:     5, K: 14476, alpha:    4.015, sigma: 0.494, c:   25.082, lamb:  7202, lp:  -206613.923
# writing to file...
# done!
# iter:     6, K: 14476, alpha:    4.161, sigma: 0.488, c:   25.096, lamb:  7205, lp:  -206587.688
# writing to file...
# done!
# iter:     7, K: 14476, alpha:    4.296, sigma: 0.482, c:   25.109, lamb:  7133, lp:  -206565.387
# writing to file...
# done!
# iter:     8, K: 14476, alpha:    4.423, sigma: 0.479, c:   25.122, lamb:  7208, lp:  -206546.419
# writing to file...
# done!
# iter:     9, K: 14476, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7264, lp:  -206529.676
# writing to file...
# done!

# %%
save_every = 100
write_every = 100
niter = 5000

model.sample(
    num_iters= niter,
    save_every = save_every,  
    write_every = write_every,
    verbose = True,
    sample_hypers = False,
    optim_hypers = False,
    num_sm = 10,
    hyper_start = 0,
    num_hyper = 10,
    do_gibbs = False,
    filename='arxiv.pkl')
# Out:
# iter:     0, K: 14476, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7228, lp:  -206529.676
# iter:   100, K: 14466, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7199, lp:  -206440.542
# writing to file...
# done!
# iter:   200, K: 14452, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7275, lp:  -206294.208
# writing to file...
# done!
# iter:   300, K: 14438, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7192, lp:  -206166.105
# writing to file...
# done!
# iter:   400, K: 14425, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7173, lp:  -206009.781
# writing to file...
# done!
# iter:   500, K: 14416, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7209, lp:  -205905.232
# writing to file...
# done!
# iter:   600, K: 14408, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7136, lp:  -205825.679
# writing to file...
# done!
# iter:   700, K: 14392, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7231, lp:  -205656.775
# writing to file...
# done!
# iter:   800, K: 14378, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7239, lp:  -205483.808
# writing to file...
# done!
# iter:   900, K: 14372, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7155, lp:  -205441.235
# writing to file...
# done!
# iter:  1000, K: 14361, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7176, lp:  -205281.299
# writing to file...
# done!
# iter:  1100, K: 14353, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7192, lp:  -205189.162
# writing to file...
# done!
# iter:  1200, K: 14340, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7179, lp:  -204997.448
# writing to file...
# done!
# iter:  1300, K: 14327, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7060, lp:  -204834.243
# writing to file...
# done!
# iter:  1400, K: 14316, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7340, lp:  -204725.959
# writing to file...
# done!
# iter:  1500, K: 14312, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7212, lp:  -204643.680
# writing to file...
# done!
# iter:  1600, K: 14304, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7254, lp:  -204509.722
# writing to file...
# done!
# iter:  1700, K: 14291, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7153, lp:  -204337.273
# writing to file...
# done!
# iter:  1800, K: 14284, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7141, lp:  -204240.997
# writing to file...
# done!
# iter:  1900, K: 14278, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7095, lp:  -204144.870
# writing to file...
# done!
# iter:  2000, K: 14263, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7150, lp:  -203928.366
# writing to file...
# done!
# iter:  2100, K: 14252, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7073, lp:  -203832.475
# writing to file...
# done!
# iter:  2200, K: 14241, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7148, lp:  -203703.283
# writing to file...
# done!
# iter:  2300, K: 14231, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7078, lp:  -203498.868
# writing to file...
# done!
# iter:  2400, K: 14223, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7153, lp:  -203383.751
# writing to file...
# done!
# iter:  2500, K: 14212, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7071, lp:  -203274.034
# writing to file...
# done!
# iter:  2600, K: 14202, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  6987, lp:  -203072.697
# writing to file...
# done!
# iter:  2700, K: 14192, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7054, lp:  -202862.744
# writing to file...
# done!
# iter:  2800, K: 14188, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7074, lp:  -202797.298
# writing to file...
# done!
# iter:  2900, K: 14187, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7079, lp:  -202777.020
# writing to file...
# done!
# iter:  3000, K: 14180, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7111, lp:  -202685.765
# writing to file...
# done!
# iter:  3100, K: 14174, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7082, lp:  -202594.271
# writing to file...
# done!
# iter:  3200, K: 14169, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7110, lp:  -202512.849
# writing to file...
# done!
# iter:  3300, K: 14168, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7114, lp:  -202475.326
# writing to file...
# done!
# iter:  3400, K: 14166, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7048, lp:  -202440.487
# writing to file...
# done!
# iter:  3500, K: 14163, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7154, lp:  -202349.980
# writing to file...
# done!
# iter:  3600, K: 14159, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7029, lp:  -202297.842
# writing to file...
# done!
# iter:  3700, K: 14155, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7091, lp:  -202258.590
# writing to file...
# done!
# iter:  3800, K: 14148, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7110, lp:  -202016.594
# writing to file...
# done!
# iter:  3900, K: 14143, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  6983, lp:  -201883.732
# writing to file...
# done!
# iter:  4000, K: 14140, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  6969, lp:  -201848.988
# writing to file...
# done!
# iter:  4100, K: 14138, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  6979, lp:  -201820.855
# writing to file...
# done!
# iter:  4200, K: 14136, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7094, lp:  -201795.396
# writing to file...
# done!
# iter:  4300, K: 14133, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7000, lp:  -201751.056
# writing to file...
# done!
# iter:  4400, K: 14132, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7038, lp:  -201741.517
# writing to file...
# done!
# iter:  4500, K: 14127, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7052, lp:  -201656.505
# writing to file...
# done!
# iter:  4600, K: 14125, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7130, lp:  -201637.889
# writing to file...
# done!
# iter:  4700, K: 14119, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  6925, lp:  -201522.712
# writing to file...
# done!
# iter:  4800, K: 14117, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7062, lp:  -201461.520
# writing to file...
# done!
# iter:  4900, K: 14113, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  6957, lp:  -201404.510
# writing to file...
# done!

# %%
save_every = 10
write_every = 50
niter = 5000

model.sample(
    num_iters= niter,
    save_every = save_every,  
    write_every = write_every,
    verbose = True,
    sample_hypers = False,
    optim_hypers = True,
    num_sm = 10,
    hyper_start = 0,
    num_hyper = 10,
    do_gibbs = False,
    filename='arxiv.pkl')
# Out:
# iter:     0, K: 14110, alpha:    4.540, sigma: 0.474, c:   25.136, lamb:  7025, lp:  -201349.061
# iter:    10, K: 14110, alpha:    4.739, sigma: 0.467, c:   25.160, lamb:  7052, lp:  -201324.478
# iter:    20, K: 14109, alpha:    4.919, sigma: 0.459, c:   25.186, lamb:  6907, lp:  -201296.071
# iter:    30, K: 14106, alpha:    5.079, sigma: 0.455, c:   25.211, lamb:  7060, lp:  -201230.680
# iter:    40, K: 14106, alpha:    5.226, sigma: 0.450, c:   25.232, lamb:  6994, lp:  -201217.535
# iter:    50, K: 14104, alpha:    5.359, sigma: 0.446, c:   25.253, lamb:  7110, lp:  -201167.528
# writing to file...
# done!
# iter:    60, K: 14104, alpha:    5.481, sigma: 0.442, c:   25.272, lamb:  7038, lp:  -201158.272
# iter:    70, K: 14103, alpha:    5.595, sigma: 0.437, c:   25.291, lamb:  7008, lp:  -201131.395
# iter:    80, K: 14103, alpha:    5.700, sigma: 0.434, c:   25.311, lamb:  7116, lp:  -201124.474
# iter:    90, K: 14103, alpha:    5.799, sigma: 0.431, c:   25.331, lamb:  7103, lp:  -201118.427
# iter:   100, K: 14103, alpha:    5.891, sigma: 0.429, c:   25.349, lamb:  7077, lp:  -201113.118
# writing to file...
# done!
# iter:   110, K: 14102, alpha:    5.978, sigma: 0.426, c:   25.368, lamb:  7111, lp:  -201091.497
# iter:   120, K: 14101, alpha:    6.059, sigma: 0.423, c:   25.381, lamb:  7083, lp:  -201070.233
# iter:   130, K: 14101, alpha:    6.135, sigma: 0.421, c:   25.398, lamb:  7123, lp:  -201066.601
# iter:   140, K: 14101, alpha:    6.206, sigma: 0.419, c:   25.416, lamb:  7047, lp:  -201063.351
# iter:   150, K: 14101, alpha:    6.274, sigma: 0.417, c:   25.433, lamb:  7001, lp:  -201060.458
# writing to file...
# done!
# iter:   160, K: 14101, alpha:    6.338, sigma: 0.415, c:   25.448, lamb:  6950, lp:  -201057.818
# iter:   170, K: 14098, alpha:    6.399, sigma: 0.414, c:   25.462, lamb:  7109, lp:  -200895.691
# iter:   180, K: 14097, alpha:    6.456, sigma: 0.412, c:   25.476, lamb:  7073, lp:  -200877.531
# iter:   190, K: 14097, alpha:    6.511, sigma: 0.410, c:   25.492, lamb:  7027, lp:  -200875.593
# iter:   200, K: 14097, alpha:    6.563, sigma: 0.409, c:   25.508, lamb:  6988, lp:  -200873.827
# writing to file...
# done!
# iter:   210, K: 14097, alpha:    6.613, sigma: 0.407, c:   25.520, lamb:  7018, lp:  -200872.265
# iter:   220, K: 14097, alpha:    6.661, sigma: 0.406, c:   25.530, lamb:  7120, lp:  -200870.828
# iter:   230, K: 14097, alpha:    6.706, sigma: 0.405, c:   25.543, lamb:  7168, lp:  -200869.503
# iter:   240, K: 14097, alpha:    6.749, sigma: 0.404, c:   25.560, lamb:  7030, lp:  -200868.260
# iter:   250, K: 14095, alpha:    6.790, sigma: 0.403, c:   25.575, lamb:  6976, lp:  -200847.718
# writing to file...
# done!
# iter:   260, K: 14095, alpha:    6.829, sigma: 0.402, c:   25.590, lamb:  7080, lp:  -200846.667
# iter:   270, K: 14094, alpha:    6.867, sigma: 0.400, c:   25.603, lamb:  6987, lp:  -200828.057
# iter:   280, K: 14094, alpha:    6.903, sigma: 0.399, c:   25.618, lamb:  7057, lp:  -200827.158
# iter:   290, K: 14093, alpha:    6.937, sigma: 0.398, c:   25.632, lamb:  7024, lp:  -200810.204
# iter:   300, K: 14092, alpha:    6.970, sigma: 0.397, c:   25.648, lamb:  7109, lp:  -200800.394
# writing to file...
# done!
# iter:   310, K: 14091, alpha:    7.002, sigma: 0.397, c:   25.663, lamb:  7038, lp:  -200781.716
# iter:   320, K: 14090, alpha:    7.032, sigma: 0.396, c:   25.677, lamb:  6988, lp:  -200771.946
# iter:   330, K: 14090, alpha:    7.065, sigma: 0.395, c:   25.694, lamb:  7056, lp:  -200771.252
# iter:   340, K: 14090, alpha:    7.092, sigma: 0.394, c:   25.708, lamb:  7123, lp:  -200770.694
# iter:   350, K: 14090, alpha:    7.118, sigma: 0.393, c:   25.722, lamb:  6999, lp:  -200770.175
# writing to file...
# done!
# iter:   360, K: 14090, alpha:    7.144, sigma: 0.393, c:   25.737, lamb:  6964, lp:  -200769.675
# iter:   370, K: 14090, alpha:    7.168, sigma: 0.392, c:   25.752, lamb:  7132, lp:  -200769.216
# iter:   380, K: 14090, alpha:    7.192, sigma: 0.391, c:   25.768, lamb:  6989, lp:  -200768.773
# iter:   390, K: 14090, alpha:    7.214, sigma: 0.391, c:   25.782, lamb:  7070, lp:  -200768.371
# iter:   400, K: 14089, alpha:    7.236, sigma: 0.390, c:   25.794, lamb:  6948, lp:  -200756.901
# writing to file...
# done!
# iter:   410, K: 14089, alpha:    7.256, sigma: 0.390, c:   25.807, lamb:  7100, lp:  -200756.554
# iter:   420, K: 14089, alpha:    7.277, sigma: 0.389, c:   25.825, lamb:  7075, lp:  -200756.182
# iter:   430, K: 14089, alpha:    7.295, sigma: 0.388, c:   25.837, lamb:  7144, lp:  -200755.883
# iter:   440, K: 14089, alpha:    7.320, sigma: 0.388, c:   25.854, lamb:  7065, lp:  -200755.501
# iter:   450, K: 14089, alpha:    7.337, sigma: 0.388, c:   25.869, lamb:  7074, lp:  -200755.213
# writing to file...
# done!
# iter:   460, K: 14089, alpha:    7.355, sigma: 0.387, c:   25.880, lamb:  6919, lp:  -200754.952
# iter:   470, K: 14089, alpha:    7.372, sigma: 0.387, c:   25.893, lamb:  7030, lp:  -200754.711
# iter:   480, K: 14089, alpha:    7.388, sigma: 0.386, c:   25.906, lamb:  7002, lp:  -200754.465
# iter:   490, K: 14089, alpha:    7.405, sigma: 0.386, c:   25.925, lamb:  6969, lp:  -200754.177
# iter:   500, K: 14088, alpha:    7.428, sigma: 0.385, c:   25.953, lamb:  7123, lp:  -200744.112
# writing to file...
# done!
# iter:   510, K: 14088, alpha:    7.443, sigma: 0.385, c:   25.970, lamb:  7014, lp:  -200743.875
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-653da3ba3895> in <module>()
#      14     num_hyper = 10,
#      15     do_gibbs = False,
# ---> 16     filename='arxiv.pkl')
#
# C:\Github\sparsedense3\sparsedense.py in sample(self, num_iters, num_sm, num_hyper, save_every, write_every, sample_hypers, optim_hypers, hyper_start, do_gibbs, burnin, verbose, filename, true_Z, write_Z, optim_momentum)
#     168                     self.alpha, self.sigma, self.c = opt.optimize_hypers2(
#     169                         self.Z, self.alpha, self.sigma, self.c, momentum = optim_momentum,
# --> 170                         num_iters = num_hyper, verbose=False, h = 1e-8)
#     171
#     172
#
# C:\Github\sparsedense3\optim.py in optimize_hypers(Z, alpha, sigma, c, num_iters, print_every, init_stepsize, momentum_free_iters, momentum, optimize_alpha, optimize_sigma, optimize_c, h, verbose)
#     100         # gradients again
#     101         ll = loglik(mk, Z, alpha, sigma, c)
# --> 102         alpha_grad, sigma_grad, c_grad = loglik_grad(mk, Z, alpha, sigma, c, h)
#     103         step = backtrack_search(mk, Z, alpha, sigma, c, ll, alpha_grad, sigma_grad, c_grad, max(8 * step, 1e-7))
#     104
#
# C:\Github\sparsedense3\optim.py in loglik_grad(mk, Z, alpha, sigma, c, h)
#      43 def loglik_grad(mk, Z, alpha, sigma, c, h):
#      44     N, K = Z.shape
# ---> 45     const = np.sum(np.array([poiss_param(1., sigma, c, n) for n in range(N)]))
#      46     alpha_grad = K/alpha - const
#      47     sigma_grad = 0.5 * (loglik(mk, Z, alpha, sigma+h, c) - loglik(mk, Z, alpha, sigma-h, c)) / h
#
# C:\Github\sparsedense3\optim.py in <listcomp>(.0)
#      43 def loglik_grad(mk, Z, alpha, sigma, c, h):
#      44     N, K = Z.shape
# ---> 45     const = np.sum(np.array([poiss_param(1., sigma, c, n) for n in range(N)]))
#      46     alpha_grad = K/alpha - const
#      47     sigma_grad = 0.5 * (loglik(mk, Z, alpha, sigma+h, c) - loglik(mk, Z, alpha, sigma-h, c)) / h
#
# C:\Github\sparsedense3\optim.py in poiss_param(alpha, sigma, c, i)
#       7
#       8 def poiss_param(alpha, sigma, c, i):
# ----> 9     lpp = np.log(alpha) + gammaln(1+c) + gammaln(i+c+sigma) - gammaln(i+1+c) - gammaln(c+sigma)
#      10     if np.isnan(lpp):
#      11         pdb.set_trace()
#
# KeyboardInterrupt:

# %%
# with open('arxiv_king.pkl', 'wb') as f:
#     pickle.dump(model, f)

# %%
model.c = 700

# %%
save_every = 1
write_every = 1
niter = 15000

model.sample(
    num_iters= niter,
    save_every = save_every,  
    write_every = write_every,
    verbose = True,
    sample_hypers = False,
    optim_hypers = True,
    num_sm = 100,
    hyper_start = 0,
    num_hyper = 10,
    do_gibbs = False,
    filename='arxiv.pkl')
# Out:
# iter:     0, K: 14079, alpha:    4.492, sigma: 0.307, c:  500.000, lamb:  7105, lp:  -203293.892
# iter:     1, K: 14079, alpha:    2.687, sigma: 0.089, c:  499.987, lamb:  7017, lp:  -199896.265
# writing to file...
# done!
# iter:     2, K: 14079, alpha:    2.499, sigma: 0.076, c:  499.987, lamb:  7049, lp:  -199919.540
# writing to file...
# done!
# iter:     3, K: 14079, alpha:    2.554, sigma: 0.107, c:  500.007, lamb:  7032, lp:  -199893.731
# writing to file...
# done!
# iter:     4, K: 14078, alpha:    2.448, sigma: 0.057, c:  500.027, lamb:  7068, lp:  -199949.098
# writing to file...
# done!
# iter:     5, K: 14078, alpha:    2.561, sigma: 0.110, c:  500.058, lamb:  7127, lp:  -199883.174
# writing to file...
# done!
# iter:     6, K: 14078, alpha:    2.542, sigma: 0.101, c:  500.085, lamb:  7073, lp:  -199885.282
# writing to file...
# done!
# iter:     7, K: 14078, alpha:    2.304, sigma: 0.076, c:  500.081, lamb:  7139, lp:  -199958.902
# writing to file...
# done!
# iter:     8, K: 14078, alpha:    2.557, sigma: 0.110, c:  500.109, lamb:  7017, lp:  -199883.163
# writing to file...
# done!
# iter:     9, K: 14077, alpha:    2.525, sigma: 0.094, c:  500.130, lamb:  7024, lp:  -199878.918
# writing to file...
# done!
# iter:    10, K: 14077, alpha:    2.502, sigma: 0.101, c:  500.146, lamb:  7055, lp:  -199876.898
# writing to file...
# done!
# iter:    11, K: 14077, alpha:    2.499, sigma: 0.104, c:  500.124, lamb:  7014, lp:  -199875.995
# writing to file...
# done!
# iter:    12, K: 14077, alpha:    2.499, sigma: 0.105, c:  500.118, lamb:  7058, lp:  -199875.390
# writing to file...
# done!
# iter:    13, K: 14076, alpha:    2.264, sigma: 0.065, c:  500.136, lamb:  7084, lp:  -199976.470
# writing to file...
# done!
# iter:    14, K: 14076, alpha:    2.544, sigma: 0.113, c:  500.152, lamb:  6988, lp:  -199863.200
# writing to file...
# done!
# iter:    15, K: 14076, alpha:    2.559, sigma: 0.109, c:  500.155, lamb:  7062, lp:  -199863.195
# writing to file...
# done!
# iter:    16, K: 14076, alpha:    2.509, sigma: 0.086, c:  500.169, lamb:  7081, lp:  -199877.248
# writing to file...
# done!
# iter:    17, K: 14076, alpha:    2.544, sigma: 0.110, c:  500.189, lamb:  7057, lp:  -199863.330
# writing to file...
# done!
# iter:    18, K: 14076, alpha:    2.472, sigma: 0.069, c:  500.181, lamb:  7084, lp:  -199902.850
# writing to file...
# done!
# iter:    19, K: 14076, alpha:    2.555, sigma: 0.111, c:  500.214, lamb:  7028, lp:  -199863.122
# writing to file...
# done!
# iter:    20, K: 14076, alpha:    2.559, sigma: 0.111, c:  500.215, lamb:  7071, lp:  -199863.106
# writing to file...
# done!
# iter:    21, K: 14075, alpha:    2.561, sigma: 0.111, c:  500.215, lamb:  7021, lp:  -199861.069
# writing to file...
# done!
# iter:    22, K: 14075, alpha:    2.561, sigma: 0.111, c:  500.215, lamb:  7078, lp:  -199861.069
# writing to file...
# done!
# iter:    23, K: 14074, alpha:    2.561, sigma: 0.111, c:  500.215, lamb:  7007, lp:  -199841.558
# writing to file...
# done!
# iter:    24, K: 14074, alpha:    2.562, sigma: 0.111, c:  500.217, lamb:  7086, lp:  -199841.556
# writing to file...
# done!
# iter:    25, K: 14074, alpha:    2.562, sigma: 0.111, c:  500.217, lamb:  7038, lp:  -199841.556
# writing to file...
# done!
# iter:    26, K: 14074, alpha:    2.562, sigma: 0.111, c:  500.268, lamb:  7167, lp:  -199841.529
# writing to file...
# done!
# iter:    27, K: 14074, alpha:    2.563, sigma: 0.111, c:  500.276, lamb:  6992, lp:  -199841.524
# writing to file...
# done!
# iter:    28, K: 14074, alpha:    2.564, sigma: 0.110, c:  500.292, lamb:  7056, lp:  -199841.515
# writing to file...
# done!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-adf9bf626b90> in <module>()
#      14     num_hyper = 10,
#      15     do_gibbs = False,
# ---> 16     filename='arxiv.pkl')
#
# C:\Github\sparsedense3\sparsedense.py in sample(self, num_iters, num_sm, num_hyper, save_every, write_every, sample_hypers, optim_hypers, hyper_start, do_gibbs, burnin, verbose, filename, true_Z, write_Z, optim_momentum)
#     152             if true_Z is False:
#     153                 for sm in range(num_sm):
# --> 154                     self.splitmerge()
#     155
#     156             if sample_hypers:
#
# KeyboardInterrupt:

# %%
model.c = 900

# %%
save_every = 2
write_every = 2
niter = 15000

model.sample(
    num_iters= niter,
    save_every = save_every,  
    write_every = write_every,
    verbose = True,
    sample_hypers = False,
    optim_hypers = True,
    num_sm = 100,
    hyper_start = 0,
    num_hyper = 20,
    optim_momentum = 0.8,
    do_gibbs = False,
    filename='arxiv.pkl')
# Out:
# iter:     0, K: 14055, alpha:    2.282, sigma: 0.017, c:  900.000, lamb:  7017, lp:  -199487.872
# iter:     2, K: 14055, alpha:    2.071, sigma: 0.000, c:  899.985, lamb:  7017, lp:  -199441.382
# writing to file...
# done!
# iter:     4, K: 14055, alpha:    2.071, sigma: 0.000, c:  899.985, lamb:  7058, lp:  -199441.382
# writing to file...
# done!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-2d68e9e9c5f8> in <module>()
#      15     optim_momentum = 0.8,
#      16     do_gibbs = False,
# ---> 17     filename='arxiv.pkl')
#
# C:\Github\sparsedense3\sparsedense.py in sample(self, num_iters, num_sm, num_hyper, save_every, write_every, sample_hypers, optim_hypers, hyper_start, do_gibbs, burnin, verbose, filename, true_Z, write_Z, optim_momentum)
#     152             if true_Z is False:
#     153                 for sm in range(num_sm):
# --> 154                     self.splitmerge()
#     155
#     156             if sample_hypers:
#
# C:\Github\sparsedense3\sparsedense.py in splitmerge(self)
#     534
#     535             ZZ = np.outer(Z_prop,Z_prop)
# --> 536             check_ZZ = (1-self.network)*ZZ
#     537             np.fill_diagonal(check_ZZ,0)
#     538             if np.sum(check_ZZ)==0:
#
# KeyboardInterrupt:

# %%
model.c = 50

# %%
save_every = 25
write_every = 25
niter = 5000
model.sample(
    num_iters= niter,
    save_every = save_every,  
    write_every = write_every,
    verbose = True,
    sample_hypers = False,
    optim_hypers = True,
    num_sm = 10,
    hyper_start = 0,
    num_hyper = 10,
    optim_momentum = 0.8,
    do_gibbs = False,
    filename='arxiv.pkl')
# Out:
# iter:     0, K: 14037, alpha:    5.800, sigma: 0.345, c:   53.097, lamb:  6934, lp:  -199772.824
# iter:    25, K: 14037, alpha:    5.800, sigma: 0.345, c:   53.097, lamb:  7074, lp:  -199772.824
# writing to file...
# done!
# iter:    50, K: 14037, alpha:    5.800, sigma: 0.345, c:   53.097, lamb:  6974, lp:  -199772.824
# writing to file...
# done!
# iter:    75, K: 14036, alpha:    5.798, sigma: 0.345, c:   53.149, lamb:  6947, lp:  -199756.316
# writing to file...
# done!
# iter:   100, K: 14036, alpha:    5.762, sigma: 0.344, c:   53.968, lamb:  7069, lp:  -199753.221
# writing to file...
# done!
# iter:   125, K: 14036, alpha:    5.726, sigma: 0.343, c:   54.806, lamb:  7044, lp:  -199750.080
# writing to file...
# done!
# iter:   150, K: 14036, alpha:    5.726, sigma: 0.343, c:   54.806, lamb:  6948, lp:  -199750.080
# writing to file...
# done!
# iter:   175, K: 14036, alpha:    5.726, sigma: 0.343, c:   54.806, lamb:  6945, lp:  -199750.080
# writing to file...
# done!
# iter:   200, K: 14035, alpha:    5.726, sigma: 0.343, c:   54.806, lamb:  7133, lp:  -199748.050
# writing to file...
# done!
# iter:   225, K: 14035, alpha:    5.726, sigma: 0.343, c:   54.806, lamb:  7048, lp:  -199748.050
# writing to file...
# done!
# iter:   250, K: 14035, alpha:    5.726, sigma: 0.343, c:   54.806, lamb:  7001, lp:  -199748.050
# writing to file...
# done!
# iter:   275, K: 14035, alpha:    5.726, sigma: 0.343, c:   54.806, lamb:  7032, lp:  -199748.050
# writing to file...
# done!
# iter:   300, K: 14035, alpha:    5.726, sigma: 0.343, c:   54.806, lamb:  7142, lp:  -199748.050
# writing to file...
# done!
# iter:   325, K: 14035, alpha:    5.726, sigma: 0.343, c:   54.806, lamb:  6951, lp:  -199748.050
# writing to file...
# done!
# iter:   350, K: 14034, alpha:    5.704, sigma: 0.343, c:   55.304, lamb:  6931, lp:  -199715.592
# writing to file...
# done!
# iter:   375, K: 14031, alpha:    5.684, sigma: 0.342, c:   55.789, lamb:  6977, lp:  -199660.386
# writing to file...
# done!
# iter:   400, K: 14031, alpha:    5.680, sigma: 0.342, c:   55.869, lamb:  7019, lp:  -199660.091
# writing to file...
# done!
# iter:   425, K: 14031, alpha:    5.680, sigma: 0.342, c:   55.869, lamb:  6993, lp:  -199660.091
# writing to file...
# done!
# iter:   450, K: 14031, alpha:    5.680, sigma: 0.342, c:   55.869, lamb:  6976, lp:  -199660.091
# writing to file...
# done!
# iter:   475, K: 14030, alpha:    5.679, sigma: 0.342, c:   55.886, lamb:  7060, lp:  -199641.972
# writing to file...
# done!
# iter:   500, K: 14030, alpha:    5.679, sigma: 0.342, c:   55.886, lamb:  6969, lp:  -199641.972
# writing to file...
# done!
# iter:   525, K: 14030, alpha:    5.679, sigma: 0.342, c:   55.886, lamb:  7000, lp:  -199641.972
# writing to file...
# done!
# iter:   550, K: 14030, alpha:    5.679, sigma: 0.342, c:   55.886, lamb:  7103, lp:  -199641.972
# writing to file...
# done!
# iter:   575, K: 14030, alpha:    5.679, sigma: 0.342, c:   55.886, lamb:  7014, lp:  -199641.972
# writing to file...
# done!
# iter:   600, K: 14030, alpha:    5.679, sigma: 0.342, c:   55.886, lamb:  6940, lp:  -199641.972
# writing to file...
# done!
# iter:   625, K: 14030, alpha:    5.679, sigma: 0.342, c:   55.886, lamb:  7018, lp:  -199641.972
# writing to file...
# done!
# iter:   650, K: 14030, alpha:    5.679, sigma: 0.342, c:   55.886, lamb:  7048, lp:  -199641.972
# writing to file...
# done!
# iter:   675, K: 14030, alpha:    5.679, sigma: 0.342, c:   55.886, lamb:  7036, lp:  -199641.972
# writing to file...
# done!
# iter:   700, K: 14030, alpha:    5.679, sigma: 0.342, c:   55.886, lamb:  6942, lp:  -199641.972
# writing to file...
# done!
# iter:   725, K: 14030, alpha:    5.679, sigma: 0.342, c:   55.886, lamb:  6914, lp:  -199641.972
# writing to file...
# done!
# iter:   750, K: 14030, alpha:    5.679, sigma: 0.342, c:   55.886, lamb:  7012, lp:  -199641.972
# writing to file...
# done!
# iter:   775, K: 14030, alpha:    5.679, sigma: 0.342, c:   55.886, lamb:  6891, lp:  -199641.972
# writing to file...
# done!
# iter:   800, K: 14030, alpha:    5.679, sigma: 0.342, c:   55.886, lamb:  6897, lp:  -199641.972
# writing to file...
# done!
# iter:   825, K: 14029, alpha:    5.679, sigma: 0.342, c:   55.893, lamb:  7026, lp:  -199633.851
# writing to file...
# done!
# iter:   850, K: 14029, alpha:    5.679, sigma: 0.342, c:   55.893, lamb:  6884, lp:  -199633.851
# writing to file...
# done!
# iter:   875, K: 14029, alpha:    5.679, sigma: 0.342, c:   55.893, lamb:  7073, lp:  -199633.851
# writing to file...
# done!
# iter:   900, K: 14029, alpha:    5.679, sigma: 0.342, c:   55.893, lamb:  7042, lp:  -199633.851
# writing to file...
# done!
# iter:   925, K: 14029, alpha:    5.679, sigma: 0.342, c:   55.893, lamb:  7065, lp:  -199633.851
# writing to file...
# done!
# iter:   950, K: 14029, alpha:    5.679, sigma: 0.342, c:   55.893, lamb:  7010, lp:  -199633.851
# writing to file...
# done!
# iter:   975, K: 14029, alpha:    5.679, sigma: 0.342, c:   55.893, lamb:  7114, lp:  -199633.851
# writing to file...
# done!
# iter:  1000, K: 14028, alpha:    5.671, sigma: 0.342, c:   56.055, lamb:  7052, lp:  -199622.969
# writing to file...
# done!
# iter:  1025, K: 14028, alpha:    5.671, sigma: 0.342, c:   56.055, lamb:  7063, lp:  -199622.969
# writing to file...
# done!
# iter:  1050, K: 14028, alpha:    5.671, sigma: 0.342, c:   56.055, lamb:  7057, lp:  -199622.969
# writing to file...
# done!
# iter:  1075, K: 14028, alpha:    5.671, sigma: 0.342, c:   56.055, lamb:  6912, lp:  -199622.969
# writing to file...
# done!
# iter:  1100, K: 14028, alpha:    5.671, sigma: 0.342, c:   56.055, lamb:  7056, lp:  -199622.969
# writing to file...
# done!
# iter:  1125, K: 14028, alpha:    5.671, sigma: 0.342, c:   56.055, lamb:  7024, lp:  -199622.969
# writing to file...
# done!
# iter:  1150, K: 14028, alpha:    5.671, sigma: 0.342, c:   56.055, lamb:  7007, lp:  -199622.969
# writing to file...
# done!
# iter:  1175, K: 14028, alpha:    5.671, sigma: 0.342, c:   56.055, lamb:  7007, lp:  -199622.969
# writing to file...
# done!
# iter:  1200, K: 14027, alpha:    5.661, sigma: 0.342, c:   56.324, lamb:  7054, lp:  -199602.331
# writing to file...
# done!
# iter:  1225, K: 14026, alpha:    5.656, sigma: 0.342, c:   56.452, lamb:  6926, lp:  -199592.736
# writing to file...
# done!
# iter:  1250, K: 14025, alpha:    5.645, sigma: 0.342, c:   56.730, lamb:  7073, lp:  -199582.410
# writing to file...
# done!
# iter:  1275, K: 14025, alpha:    5.645, sigma: 0.342, c:   56.730, lamb:  7027, lp:  -199582.410
# writing to file...
# done!
# iter:  1300, K: 14025, alpha:    5.645, sigma: 0.342, c:   56.730, lamb:  7139, lp:  -199582.410
# writing to file...
# done!
# iter:  1325, K: 14025, alpha:    5.645, sigma: 0.342, c:   56.730, lamb:  6991, lp:  -199582.410
# writing to file...
# done!
# iter:  1350, K: 14025, alpha:    5.645, sigma: 0.342, c:   56.730, lamb:  6929, lp:  -199582.410
# writing to file...
# done!
# iter:  1375, K: 14023, alpha:    5.644, sigma: 0.342, c:   56.763, lamb:  7011, lp:  -199544.018
# writing to file...
# done!
# iter:  1400, K: 14022, alpha:    5.638, sigma: 0.342, c:   56.881, lamb:  6968, lp:  -199527.089
# writing to file...
# done!
# iter:  1425, K: 14022, alpha:    5.638, sigma: 0.342, c:   56.881, lamb:  7038, lp:  -199527.089
# writing to file...
# done!
# iter:  1450, K: 14022, alpha:    5.638, sigma: 0.342, c:   56.881, lamb:  6989, lp:  -199527.089
# writing to file...
# done!
# iter:  1475, K: 14022, alpha:    5.638, sigma: 0.342, c:   56.881, lamb:  6998, lp:  -199527.089
# writing to file...
# done!
# iter:  1500, K: 14022, alpha:    5.638, sigma: 0.342, c:   56.881, lamb:  6928, lp:  -199527.089
# writing to file...
# done!
# iter:  1525, K: 14022, alpha:    5.638, sigma: 0.342, c:   56.881, lamb:  7007, lp:  -199527.089
# writing to file...
# done!
# iter:  1550, K: 14020, alpha:    5.636, sigma: 0.342, c:   56.950, lamb:  7005, lp:  -199497.142
# writing to file...
# done!
# iter:  1575, K: 14020, alpha:    5.636, sigma: 0.342, c:   56.950, lamb:  7110, lp:  -199497.142
# writing to file...
# done!
# iter:  1600, K: 14019, alpha:    5.636, sigma: 0.342, c:   56.959, lamb:  7041, lp:  -199487.260
# writing to file...
# done!
# iter:  1625, K: 14018, alpha:    5.624, sigma: 0.341, c:   57.243, lamb:  6987, lp:  -199432.615
# writing to file...
# done!
# iter:  1650, K: 14018, alpha:    5.624, sigma: 0.341, c:   57.243, lamb:  7056, lp:  -199432.615
# writing to file...
# done!
# iter:  1675, K: 14018, alpha:    5.624, sigma: 0.341, c:   57.243, lamb:  7016, lp:  -199432.615
# writing to file...
# done!
# iter:  1700, K: 14018, alpha:    5.624, sigma: 0.341, c:   57.243, lamb:  6950, lp:  -199432.615
# writing to file...
# done!
# iter:  1725, K: 14018, alpha:    5.624, sigma: 0.341, c:   57.243, lamb:  7026, lp:  -199432.615
# writing to file...
# done!
# iter:  1750, K: 14018, alpha:    5.624, sigma: 0.341, c:   57.243, lamb:  6965, lp:  -199432.615
# writing to file...
# done!
# iter:  1775, K: 14018, alpha:    5.624, sigma: 0.341, c:   57.243, lamb:  6912, lp:  -199432.615
# writing to file...
# done!
# iter:  1800, K: 14018, alpha:    5.624, sigma: 0.341, c:   57.243, lamb:  7031, lp:  -199432.615
# writing to file...
# done!
# iter:  1825, K: 14018, alpha:    5.624, sigma: 0.341, c:   57.243, lamb:  7036, lp:  -199432.615
# writing to file...
# done!
# iter:  1850, K: 14018, alpha:    5.624, sigma: 0.341, c:   57.243, lamb:  6998, lp:  -199432.615
# writing to file...
# done!
# iter:  1875, K: 14018, alpha:    5.624, sigma: 0.341, c:   57.243, lamb:  7014, lp:  -199432.615
# writing to file...
# done!
# iter:  1900, K: 14017, alpha:    5.623, sigma: 0.341, c:   57.247, lamb:  6985, lp:  -199412.948
# writing to file...
# done!
# iter:  1925, K: 14017, alpha:    5.623, sigma: 0.341, c:   57.247, lamb:  7056, lp:  -199412.948
# writing to file...
# done!
# iter:  1950, K: 14017, alpha:    5.623, sigma: 0.341, c:   57.247, lamb:  6951, lp:  -199412.948
# writing to file...
# done!
# iter:  1975, K: 14017, alpha:    5.623, sigma: 0.341, c:   57.247, lamb:  6982, lp:  -199412.948
# writing to file...
# done!
# iter:  2000, K: 14017, alpha:    5.623, sigma: 0.341, c:   57.247, lamb:  7019, lp:  -199412.948
# writing to file...
# done!
# iter:  2025, K: 14017, alpha:    5.623, sigma: 0.341, c:   57.247, lamb:  7064, lp:  -199412.948
# writing to file...
# done!
# iter:  2050, K: 14016, alpha:    5.618, sigma: 0.341, c:   57.362, lamb:  6979, lp:  -199394.235
# writing to file...
# done!
# iter:  2075, K: 14016, alpha:    5.589, sigma: 0.341, c:   58.038, lamb:  6994, lp:  -199391.800
# writing to file...
# done!
# iter:  2100, K: 14016, alpha:    5.589, sigma: 0.341, c:   58.038, lamb:  6986, lp:  -199391.800
# writing to file...
# done!
# iter:  2125, K: 14016, alpha:    5.589, sigma: 0.341, c:   58.038, lamb:  6967, lp:  -199391.800
# writing to file...
# done!
# iter:  2150, K: 14016, alpha:    5.589, sigma: 0.341, c:   58.038, lamb:  6976, lp:  -199391.800
# writing to file...
# done!
# iter:  2175, K: 14016, alpha:    5.589, sigma: 0.341, c:   58.038, lamb:  7017, lp:  -199391.800
# writing to file...
# done!
# iter:  2200, K: 14016, alpha:    5.589, sigma: 0.341, c:   58.038, lamb:  7002, lp:  -199391.800
# writing to file...
# done!
