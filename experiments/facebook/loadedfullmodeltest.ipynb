# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
# %matplotlib inline

# %%
with open('./facebook.pkl', 'rb') as file:
    model = pickle.load(file)

# %%
model['alphas'][-10:]
# Out:
# [2.3746229186337966,
#  2.3746229186337966,
#  2.3746229186337966,
#  2.3746229186337966,
#  2.3746229168050004,
#  2.374622916776439,
#  2.374622916776439,
#  2.374622916776439,
#  2.374622916776439,
#  2.374622916776439]

# %%
plt.plot(model['alphas'])

# %%
plt.plot(model['Ks'])

# %%
model['sigmas'][-10:]
# Out:
# [0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001]

# %%
plt.plot(model['sigmas'])

# %%
plt.plot(model['cs'])

# %%
import sys
sys.path.append('./../')
import sparsedense as spd
import helpertests as tst
import optim

# %%
Z = optim.sample_from_ibp(N=40000, alpha=2.5, sigma=0.0, c=300)

# %%
adj = np.minimum(Z.transpose() @ Z, 1)

# %%
Z.shape
# Out:
# (40000, 3704)

# %%
g = nx.from_numpy_array(adj)

# %%
tst.test_stats(g)
# Out:
# - num nodes: 3704
# - num edges: 110751
# - edge node ratio: 29.90
# - density: 0.016149
# - mean degree: 59.80
# - mean maximal clique containing node: 9.06
# - clustering coefficient: 0.42
# - connected component sizes (top 5): [3640, 1, 1, 1, 1]
# - mean distance between nodes (largest conn. comp.): 2.52
